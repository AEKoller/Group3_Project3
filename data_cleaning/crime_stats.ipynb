# %%
import requests
import json
from pprint import PrettyPrinter 
import pandas as pd

API_key = "bzUjDR5de2oFVYyOvduky9XrhQw1ClIuiky8wdV5"

# %%
agency_url = f"https://api.usa.gov/crime/fbi/cde/arrest/state/IL/all?from=2004&to=2024&API_KEY={API_key}"
print(requests.get(agency_url))
# Out:
# <Response [200]>

# %%
state_abbreviations = [
    'AL', 'AK', 'AZ', 'AR', 'CA',
    'CO', 'CT', 'DE', 'FL', 'GA',
    'HI', 'ID', 'IL', 'IN', 'IA',
    'KS', 'KY', 'LA', 'ME', 'MD',
    'MA', 'MI', 'MN', 'MS', 'MO',
    'MT', 'NE', 'NV', 'NH', 'NJ',
    'NM', 'NY', 'NC', 'ND', 'OH',
    'OK', 'OR', 'PA', 'RI', 'SC',
    'SD', 'TN', 'TX', 'UT', 'VT',
    'VA', 'WA', 'WV', 'WI', 'WY'
]

# %%
national_crime_year = pd.DataFrame()

for i in state_abbreviations:
    agency_url = f"https://api.usa.gov/crime/fbi/cde/arrest/state/{i}/all?from=2004&to=2024&API_KEY={API_key}"
    query = requests.get(agency_url).json()
    temp_df = pd.DataFrame(query["data"])
    temp_df['state_abbr'] = i
    cols = ['state_abbr'] + [col for col in temp_df.columns if col != 'state_abbr']
    temp_df = temp_df[cols]
    national_crime_year = pd.concat([national_crime_year, temp_df], ignore_index=True)

national_crime_year
# Out:
#     state_abbr  data_year  Aggravated Assault  \
# 0           AL       2004                3926
# 1           AL       2005                3389
# 2           AL       2006                2971
# 3           AL       2007                3807
# 4           AL       2008                4019
# ..         ...        ...                 ...
# 932         WY       2018                 547
# 933         WY       2019                 367
# 934         WY       2020                 435
# 935         WY       2021                 279
# 936         WY       2022                 232
#
#      All Other Offenses (Except Traffic)  Arson  Burglary  \
# 0                                  78939    121      3498
# 1                                  68569     95      2932
# 2                                  62179     95      2843
# 3                                  77383    107      3379
# 4                                  87077    141      4275
# ...

# %%
national_crime_year.to_csv('../clean_data/national_crime_year.csv', index=False)
